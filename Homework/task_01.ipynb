# %%
'''Massiv Yaratmaq: numpy kitabxanasını istifadə edərək 5 tələbənin imtahan balından ibarət birölçülü massiv yaradın və ekrana çap edin.
Orta Hesab: Yaradılmış balların orta qiymətini (np.mean) və ən yüksək balı (np.max) hesablayan kod yazın.
Məlumatın Sayı: Massivdə cəmi neçə element (bal) olduğunu .size xassəsi ilə tapın.'''
