# %%
Scikit-learn kitabxanası ilə ilk modeli təlim etmək.
Modeli Yaratmaq: LinearRegression() obyektini yaradın və mövcud $X$ və $Y$ məlumatlarınızla modeli təlim edin (.fit).
Proqnoz Vermək: Təlim olunmuş modeldən istifadə edərək, məlumat siyahısında olmayan yeni bir qiymət (məsələn, yeni bir ev sahəsi) üçün proqnoz (.predict) alın.
Proqnoz Xətti: Real məlumatları göy nöqtələrlə, modelin tapdığı proqnoz xəttini isə qırmızı rəngdə eyni qrafik üzərində çəkin.
