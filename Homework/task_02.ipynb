# %%
'''Giriş-Çıxış Ayırması: "Evin sahəsi" ($X$) və "Evin qiyməti" ($Y$) məlumatlarını iki ayrı massiv kimi yaradın.
Məlumatın Ölçüsü: Giriş məlumatlarını ($X$) maşın öyrənməsi modelinin qəbul edəcəyi sütun şəklində olan ikiölçülü massivə çevirin (.reshape(-1, 1)).
Vizuallaşdırma: matplotlib kitabxanasından istifadə edərək bu məlumatları sadə nöqtəli qrafik (plt.scatter) şəklində göstərin.'''
